# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Account ID from ARN\n\nHere's a solution to extract the AWS account ID from an ARN string:\n\n```python\ndef extract_account_id(arn):\n    \"\"\"\n    Extract AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn (str): The ARN string\n        \n    Returns:\n        str: The account ID, or empty string if not present\n    \"\"\"\n    parts = arn.split(':')\n    \n    # ARN format has 6 parts, account ID is at index 4\n    if len(parts) >= 5:\n        return parts[4]\n    return \"\"\n\n\n# Test cases\ntest_arns = [\n    'arn:aws:s3:::my-bucket/path/to/object',\n    'arn:aws:iam::123456789012:user/Development/product_1234/*',\n    'arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0',\n    'arn:aws:rds:us-east-1:123456789012:db:mysql-db1',\n]\n\nfor arn in test_arns:\n    account_id = extract_account_id(arn)\n    print(f\"ARN: {arn}\")\n    print(f\"Account ID: {account_id if account_id else '(empty/not applicable)'}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:s3:::my-bucket/path/to/object\nAccount ID: (empty/not applicable)\n\nARN: arn:aws:iam::123456789012:user/Development/product_1234/*\nAccount ID: 123456789012\n\nARN: arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: arn:aws:rds:us-east-1:123456789012:db:mysql-db1\nAccount ID: 123456789012\n```\n\n## Key Points:\n\n1. **ARN Structure**: `arn:partition:service:region:account-id:resource-type/resource-id`\n2. **Account ID Position**: Always at index 4 (5th element) when splitting by `:`\n3. **Empty Fields**: Some services (like S3) don't include an account ID, so the field is empty\n4. The function returns an empty string if the account ID is not present",
#     "test_case": {
#       "task": "Extract the AWS account ID from an ARN string like 'arn:aws:s3:::my-bucket/path/to/object'",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated problem of extracting account IDs from ARN strings. The logic is sound and handles the AWS ARN format properly, including the important edge case of S3 buckets which don't have account IDs. The test cases effectively demonstrate the function's behavior. However, the code lacks robustness in input validation and error handling. For a production AWS utility, it should validate inputs and provide clear feedback when ARNs are malformed. The solution would benefit from explicit documentation that empty account IDs are expected for certain AWS services like S3."
#   },
#   {
#     "output": "# AWS Lambda Function Configuration (JSON)\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 512,\n  \"Description\": \"Lambda function with Python 3.11 runtime\"\n}\n```\n\n## Explanation of Key Properties:\n\n| Property | Value | Description |\n|----------|-------|-------------|\n| `FunctionName` | string | Name of the Lambda function |\n| `Runtime` | `python3.11` | Python 3.11 runtime environment |\n| `Role` | ARN string | IAM execution role (required permissions) |\n| `Handler` | `index.handler` | Entry point (filename.function_name) |\n| `Timeout` | `60` | Maximum execution time in seconds |\n| `MemorySize` | `512` | Memory allocation in MB (128-10,240) |\n| `Description` | string | Optional function description |\n\n## Usage Example with AWS CLI:\n\n```bash\naws lambda create-function --cli-input-json file://lambda-config.json\n```\n\n## Minimal Configuration:\n\n```json\n{\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 60,\n  \"MemorySize\": 512\n}\n```\n\nThis configuration meets your requirements with the specified runtime, timeout, and memory settings.",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies runtime as Python 3.11, timeout of 60 seconds, and memory of 512 MB",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution accurately delivers all three core requirements in valid JSON format with correct values. The supplementary explanations and examples add educational value. However, the inclusion of optional/additional properties (Role, Handler, FunctionName, Description) goes beyond the task scope. While this demonstrates AWS best practices, it slightly deviates from the focused requirement. The minimal configuration section is helpful but creates some redundancy. Overall, a strong response that meets requirements but could be more concise."
#   },
#   {
#     "output": "# AWS S3 Object Key to File Extension\n\nHere's a simple and robust solution:\n\n```python\nimport os\n\ndef get_s3_file_extension(s3_key: str) -> str:\n    \"\"\"\n    Extract file extension from an AWS S3 object key.\n    \n    Args:\n        s3_key (str): The S3 object key (path)\n        \n    Returns:\n        str: The file extension (including the dot), or empty string if no extension\n        \n    Example:\n        >>> get_s3_file_extension(\"my-bucket/documents/file.pdf\")\n        \".pdf\"\n        >>> get_s3_file_extension(\"path/to/image.jpg\")\n        \".jpg\"\n        >>> get_s3_file_extension(\"path/to/archive.tar.gz\")\n        \".gz\"\n    \"\"\"\n    _, extension = os.path.splitext(s3_key)\n    return extension\n```\n\n## Alternative Implementations\n\n**If you want just the extension without the dot:**\n\n```python\ndef get_s3_file_extension(s3_key: str) -> str:\n    \"\"\"Returns file extension without the dot.\"\"\"\n    _, extension = os.path.splitext(s3_key)\n    return extension.lstrip('.')\n```\n\n**If you want to handle compound extensions (e.g., `.tar.gz`):**\n\n```python\ndef get_s3_file_extension(s3_key: str, include_dot: bool = True) -> str:\n    \"\"\"\n    Extract file extension from S3 key, with support for compound extensions.\n    \n    Args:\n        s3_key (str): The S3 object key\n        include_dot (bool): Whether to include the dot in the result\n        \n    Returns:\n        str: The file extension\n    \"\"\"\n    # Get the filename from the full path\n    filename = os.path.basename(s3_key)\n    \n    # Handle compound extensions like .tar.gz\n    if filename.count('.') > 1:\n        parts = filename.split('.')\n        if parts[-2] == 'tar':  # Special case for .tar.gz, .tar.bz2, etc.\n            extension = f\".{parts[-2]}.{parts[-1]}\"\n        else:\n            extension = f\".{parts[-1]}\"\n    else:\n        _, extension = os.path.splitext(filename)\n    \n    return extension if include_dot else extension.lstrip('.')\n```\n\n## Usage Examples\n\n```python\n# Basic usage\nprint(get_s3_file_extension(\"my-bucket/documents/file.pdf\"))      # .pdf\nprint(get_s3_file_extension(\"path/to/image.jpg\"))                  # .jpg\nprint(get_s3_file_extension(\"path/to/file.tar.gz\"))                # .gz (or .tar.gz with advanced version)\nprint(get_s3_file_extension(\"path/to/no_extension\"))               # (empty string)\nprint(get_s3_file_extension(\"folder/subfolder/document.docx\"))     # .docx\n```\n\n## Why `os.path.splitext()` is ideal:\n\n\u2705 **Simple and readable** - one line of code  \n\u2705 **Standard library** - no external dependencies  \n\u2705 **Handles edge cases** - files with no extension, multiple dots, etc.  \n\u2705 **Cross-platform** - works on Windows, Linux, macOS  \n\u2705 **Efficient** - minimal overhead  \n\nThe first solution is recommended for most use cases as it's simple and covers the standard requirements.",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 object key and returns the file extension",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively addresses the stated task with a straightforward, dependency-free approach. The primary implementation is solid and appropriate. However, the alternative implementations introduce complexity that doesn't fully solve the stated problems - the compound extension handler has logic that won't generalize, and the documentation creates false expectations about behavior. The solution would benefit from either simplifying the alternatives or making them genuinely robust. For the core requirement, this is a good solution; the weaknesses primarily concern the additional alternatives presented."
#   }
# ]
